# %% [markdown]
# Robot Localization with Python and Particle Filters
# ===================================================

# %% [markdown]
# Import libraries and load map.

# %%
import numpy as np
import cv2

map = cv2.imread("map.png", 0)
HEIGHT, WIDTH = map.shape
print(map)

rx, ry, rtheta = (WIDTH/4, HEIGHT/4, 0)
# Out:
# [[ 79  80  82 ... 133 148 156]
#  [ 78  79  81 ... 138 156 164]
#  [ 76  77  79 ... 147 170 180]
#  ...
#  [181 181 182 ... 174 172 171]
#  [178 178 178 ... 180 179 178]
#  [177 177 177 ... 183 182 182]]

# %% [markdown]
# Map coordinate system
#
# ![title](images/coords.png)
#
# CAUTION: The terrain height at X,Y coordinates is map(Y,X).

# %% [markdown]
# Read keyboard input.

# %%
STEP = 5
TURN = np.radians(25)
def get_input():
    fwd = 0
    turn = 0
    halt = False
    k = cv2.waitKey(0)
    if k == 82:
        fwd = STEP
    elif k == 83:
        turn = TURN
    elif k == 81:
        turn = -TURN
    else:
        halt = True

    return fwd, turn, halt

# %% [markdown]
# Move the robot, with Gausssian noise.
#
# ![title](images/gaussian.png)

# %%
SIGMA_STEP = 0.5
SIGMA_TURN = np.radians(5)
def move_robot(rx, ry, rtheta, fwd, turn):
    fwd_noisy = np.random.normal(fwd, SIGMA_STEP, 1)
    rx += fwd_noisy * np.cos(rtheta)
    ry += fwd_noisy * np.sin(rtheta)
    print("fwd_noisy=", fwd_noisy)
    
    turn_noisy = np.random.normal(turn, SIGMA_TURN, 1)
    rtheta += turn_noisy
    print("turn_noisy=", np.degrees(turn_noisy))
    return rx, ry, rtheta

# %% [markdown]
# Initialize particle cloud.

# %%
NUM_PARTICLES = 3000
def init():
    particles = np.random.rand(NUM_PARTICLES, 3)
    particles *= np.array((WIDTH, HEIGHT, np.radians(360)))
    return particles

# %% [markdown]
# Move the particles.

# %%
def move_particles(particles, fwd, turn):
    particles[:, 0] += fwd * np.cos(particles[:, 2])
    particles[:, 1] += fwd * np.sin(particles[:, 2])
    particles[:, 2] += turn
    
    particles[:,0] = np.clip(particles[:,0], 0.0, WIDTH-1)
    particles[:,1] = np.clip(particles[:,1], 0.0, HEIGHT-1)
    return particles

# %% [markdown]
# Get value from robot's sensor.

# %%
def sense(x, y, noisy=False):
    SIGMA_SENSOR = 5
    x = int(x)
    y = int(y)
    if noisy:
        return map[y,x] + np.random.normal(0.0, SIGMA_SENSOR, 1)
    return map[y, x]

# %% [markdown]
# Compute particle weights.

# %%
def compute_weights(particles, robot_sensor):    
    errors = np.zeros(NUM_PARTICLES)
    for i in range(NUM_PARTICLES):
        elevation = sense(particles[i, 0], particles[i, 1], noisy=False)
        errors[i] = abs(robot_sensor - elevation)
    weights = np.max(errors) - errors
    
    weights[
        (particles[:,0] == 0) |
        (particles[:,0] == WIDTH-1) |
        (particles[:,1] == 0) |
        (particles[:,1] == HEIGHT-1)
    ] = 0.0
    
    weights = weights ** 3
    return weights

# %% [markdown]
# Resample the particles.

# %%
def resample(particles, weights):
    probabilities = weights / np.sum(weights)
    new_index = np.random.choice(
        NUM_PARTICLES,
        size = NUM_PARTICLES,
        p = probabilities)
    particles = particles[new_index, :]
    return particles

# %% [markdown]
# Add noise to the particles.

# %%
SIGMA_POS = 2
SIGMA_TURN = np.radians(10)
def add_noise(particles):
    noise = np.concatenate((
        np.random.normal(0, SIGMA_POS, (NUM_PARTICLES, 1)),
        np.random.normal(0, SIGMA_POS, (NUM_PARTICLES, 1)),
        np.random.normal(0, SIGMA_TURN, (NUM_PARTICLES, 1))
        ),
        axis=1   
    )
    particles += noise
    return particles

# %% [markdown]
# Display robot, particles and best guess.

# %%
def display(map, rx, ry, particles):
    lmap = cv2.cvtColor(map, cv2.COLOR_GRAY2BGR)
    
    # Display particles
    if len(particles) > 0:
        for i in range(NUM_PARTICLES):
            cv2.circle(lmap, 
                       (int(particles[i,0]), int(particles[i,1])), 
                       1, 
                       (255,0,0), 
                       1)
        
    # Display robot
    cv2.circle(lmap, (int(rx), int(ry)), 5, (0,255,0), 10)

    # Display best guess
    if len(particles) > 0:
        px = np.mean(particles[:,0])
        py = np.mean(particles[:,1])
        cv2.circle(lmap, (int(px), int(py)), 5, (0,0,255), 5)

    cv2.imshow('map', lmap)

# %% [markdown]
# Main routine.

# %%
particles = init()
while True:
    display(map, rx, ry, particles)
    fwd, turn, halt = get_input()
    if halt:
        break
    rx, ry, rtheta = move_robot(rx, ry, rtheta, fwd, turn)
    particles = move_particles(particles, fwd, turn)
    if fwd != 0:
        robot_sensor = sense(rx, ry, noisy=True)        
        weights = compute_weights(particles, robot_sensor)
        particles = resample(particles, weights)
        particles = add_noise(particles)
    
cv2.destroyAllWindows()
# Out:
# fwd_noisy= [4.91208907]
# turn_noisy= [-12.87052041]
# fwd_noisy= [4.7721828]
# turn_noisy= [6.91181795]
# fwd_noisy= [4.7253157]
# turn_noisy= [2.51714423]
# fwd_noisy= [4.89966593]
# turn_noisy= [20.00602431]
# fwd_noisy= [5.1178288]
# turn_noisy= [9.02418452]
# fwd_noisy= [4.93823191]
# turn_noisy= [-33.47916731]
# fwd_noisy= [5.14502055]
# turn_noisy= [-12.29642269]
# fwd_noisy= [5.27444662]
# turn_noisy= [-1.02374045]
# fwd_noisy= [4.331567]
# turn_noisy= [7.75331609]
# fwd_noisy= [4.41548709]
# turn_noisy= [-1.48213503]
# fwd_noisy= [4.06139135]
# turn_noisy= [15.14480169]
# fwd_noisy= [5.01788305]
# turn_noisy= [-1.21511565]
# fwd_noisy= [4.62367248]
# turn_noisy= [12.3642304]
# fwd_noisy= [3.95637599]
# turn_noisy= [16.86696534]
# fwd_noisy= [5.81543085]
# turn_noisy= [10.59615402]
# fwd_noisy= [5.14694058]
# turn_noisy= [-2.80637153]
# fwd_noisy= [5.05524153]
# turn_noisy= [13.71344197]
# fwd_noisy= [4.22434181]
# turn_noisy= [8.69281965]
# fwd_noisy= [4.77914629]
# turn_noisy= [6.68972809]
# fwd_noisy= [4.77575533]
# turn_noisy= [-9.28558895]
# fwd_noisy= [3.91321061]
# turn_noisy= [4.87175811]
# fwd_noisy= [4.91911209]
# turn_noisy= [-7.12531949]
# fwd_noisy= [5.36883235]
# turn_noisy= [0.05824133]
# fwd_noisy= [3.91925885]
# turn_noisy= [-6.15377991]
# fwd_noisy= [4.6489798]
# turn_noisy= [13.81241568]
# fwd_noisy= [5.58900485]
# turn_noisy= [3.49179643]
# fwd_noisy= [4.62833949]
# turn_noisy= [-4.46979508]
# fwd_noisy= [5.34261765]
# turn_noisy= [14.58074]
# fwd_noisy= [4.46299809]
# turn_noisy= [-3.38673152]
# fwd_noisy= [4.69947792]
# turn_noisy= [-1.53001079]
# fwd_noisy= [5.69785334]
# turn_noisy= [2.1485945]
# fwd_noisy= [5.21956794]
# turn_noisy= [9.37332814]
# fwd_noisy= [5.2369115]
# turn_noisy= [-13.56752942]
# fwd_noisy= [4.98798619]
# turn_noisy= [-0.35714185]
# fwd_noisy= [5.0826269]
# turn_noisy= [-3.58083182]
# fwd_noisy= [5.76538722]
# turn_noisy= [-16.77204335]
# fwd_noisy= [5.52088133]
# turn_noisy= [4.69685147]
# fwd_noisy= [4.90692641]
# turn_noisy= [21.73742663]
# fwd_noisy= [4.48672347]
# turn_noisy= [0.68876389]
# fwd_noisy= [5.03137542]
# turn_noisy= [14.20308974]
# fwd_noisy= [5.36575825]
# turn_noisy= [9.93139426]
# fwd_noisy= [5.08595662]
# turn_noisy= [8.85061698]
# fwd_noisy= [5.05826141]
# turn_noisy= [-4.96313414]
# fwd_noisy= [5.34217623]
# turn_noisy= [-9.7826629]
# fwd_noisy= [5.86832367]
# turn_noisy= [-1.91549931]
# fwd_noisy= [4.80371592]
# turn_noisy= [-2.543238]
# fwd_noisy= [5.07870328]
# turn_noisy= [-21.5042899]
# fwd_noisy= [4.93348289]
# turn_noisy= [2.35078965]
# fwd_noisy= [5.50768833]
# turn_noisy= [21.60051227]
# fwd_noisy= [4.79848696]
# turn_noisy= [18.27803495]
# fwd_noisy= [3.74240047]
# turn_noisy= [-1.76767802]
# fwd_noisy= [5.31131405]
# turn_noisy= [1.91350449]
# fwd_noisy= [4.91598648]
# turn_noisy= [6.93248945]
# fwd_noisy= [4.56847732]
# turn_noisy= [-5.75329286]
# fwd_noisy= [5.37365147]
# turn_noisy= [-1.86995155]
# fwd_noisy= [4.46116484]
# turn_noisy= [7.98903332]
# fwd_noisy= [5.40404084]
# turn_noisy= [-0.67849542]
# fwd_noisy= [4.70763465]
# turn_noisy= [-4.79758415]
# fwd_noisy= [5.09386425]
# turn_noisy= [-9.25240586]
# fwd_noisy= [5.30942053]
# turn_noisy= [1.76347051]
# fwd_noisy= [3.9572092]
# turn_noisy= [-11.84849718]
# fwd_noisy= [5.76278066]
# turn_noisy= [-9.70649493]
# fwd_noisy= [4.29535345]
# turn_noisy= [-2.00473052]
# fwd_noisy= [4.7659615]
# turn_noisy= [2.94586707]
# fwd_noisy= [5.05124039]
# turn_noisy= [4.65326284]
# fwd_noisy= [4.22618596]
# turn_noisy= [-9.75044724]
# fwd_noisy= [4.73406109]
# turn_noisy= [-9.9203201]
# fwd_noisy= [4.82092642]
# turn_noisy= [8.5247449]
# fwd_noisy= [4.86808437]
# turn_noisy= [-27.70676557]
# fwd_noisy= [4.83861356]
# turn_noisy= [-4.81900752]
# fwd_noisy= [5.22191047]
# turn_noisy= [1.98815429]
# fwd_noisy= [5.0583173]
# turn_noisy= [7.26045883]
# fwd_noisy= [5.04290676]
# turn_noisy= [-10.31124682]
# fwd_noisy= [5.34413873]
# turn_noisy= [3.73877667]
# fwd_noisy= [4.36498341]
# turn_noisy= [1.23875637]
# fwd_noisy= [5.32973549]
# turn_noisy= [-9.51758114]
# fwd_noisy= [5.40299032]
# turn_noisy= [2.40546281]
# fwd_noisy= [4.79187652]
# turn_noisy= [6.47122723]
# fwd_noisy= [4.87534982]
# turn_noisy= [-4.48560701]
# fwd_noisy= [3.86210504]
# turn_noisy= [-6.21713136]
# fwd_noisy= [-0.43384285]
# turn_noisy= [-38.55433441]
# fwd_noisy= [-0.57498812]
# turn_noisy= [-19.67336801]
# fwd_noisy= [-0.02392085]
# turn_noisy= [-2.35646018]
# fwd_noisy= [-0.40053112]
# turn_noisy= [-35.60031265]
# fwd_noisy= [4.95950199]
# turn_noisy= [-15.81410567]
# fwd_noisy= [5.36822244]
# turn_noisy= [-13.62233387]
# fwd_noisy= [4.53623609]
# turn_noisy= [0.73948804]
# fwd_noisy= [5.43166367]
# turn_noisy= [-10.6621446]
# fwd_noisy= [4.42588499]
# turn_noisy= [-2.42094097]
# fwd_noisy= [4.88003224]
# turn_noisy= [-0.66163863]
# fwd_noisy= [4.90249006]
# turn_noisy= [-3.49678257]
# fwd_noisy= [4.26896827]
# turn_noisy= [3.63241863]
# fwd_noisy= [5.18704809]
# turn_noisy= [2.52]
# fwd_noisy= [4.88968913]
# turn_noisy= [23.97162785]
# fwd_noisy= [5.46704394]
# turn_noisy= [-0.85934229]
# fwd_noisy= [4.39078824]
# turn_noisy= [-3.92980437]
# fwd_noisy= [4.74773205]
# turn_noisy= [3.39125233]
# fwd_noisy= [4.90028986]
# turn_noisy= [-3.00217523]
# fwd_noisy= [4.70255923]
# turn_noisy= [-7.39242637]
# fwd_noisy= [5.55662397]
# turn_noisy= [36.47905183]
# fwd_noisy= [3.88048517]
# turn_noisy= [16.59395306]
# fwd_noisy= [5.65329342]
# turn_noisy= [14.24371582]
# fwd_noisy= [5.65256496]
# turn_noisy= [11.4249124]
# fwd_noisy= [5.83254287]
# turn_noisy= [-19.68473456]
# fwd_noisy= [4.6865891]
# turn_noisy= [-3.83393693]
# fwd_noisy= [4.90463213]
# turn_noisy= [-23.02878022]
# fwd_noisy= [4.63765345]
# turn_noisy= [-1.47591115]
# fwd_noisy= [5.85856867]
# turn_noisy= [-6.03952272]
# fwd_noisy= [4.81606628]
# turn_noisy= [1.74365887]
# fwd_noisy= [5.17688112]
# turn_noisy= [14.98023222]
# fwd_noisy= [4.39506617]
# turn_noisy= [-14.15012158]
# fwd_noisy= [4.71104181]
# turn_noisy= [8.97321364]
# fwd_noisy= [5.95350534]
# turn_noisy= [5.01672368]
# fwd_noisy= [-0.54323989]
# turn_noisy= [-41.61715019]
# fwd_noisy= [0.27730598]
# turn_noisy= [-25.55965704]
# fwd_noisy= [0.24712553]
# turn_noisy= [-33.48183998]
# fwd_noisy= [-0.40739978]
# turn_noisy= [-42.64341033]
# fwd_noisy= [5.10017333]
# turn_noisy= [3.74202444]
# fwd_noisy= [5.58729726]
# turn_noisy= [12.5802856]
# fwd_noisy= [5.49170158]
# turn_noisy= [-16.06895588]
# fwd_noisy= [5.34317491]
# turn_noisy= [9.90559327]
# fwd_noisy= [4.65594247]
# turn_noisy= [14.09266014]
# fwd_noisy= [4.46543906]
# turn_noisy= [3.30333969]
# fwd_noisy= [5.36929329]
# turn_noisy= [13.64612465]
# fwd_noisy= [5.62107839]
# turn_noisy= [2.75646661]
# fwd_noisy= [4.64165465]
# turn_noisy= [5.96149029]
# fwd_noisy= [4.6913604]
# turn_noisy= [3.51773267]
# fwd_noisy= [4.39780907]
# turn_noisy= [12.42481192]
# fwd_noisy= [4.49851475]
# turn_noisy= [-8.05488223]
# fwd_noisy= [5.49261215]
# turn_noisy= [4.96762812]
# fwd_noisy= [4.93169636]
# turn_noisy= [6.30929468]
# fwd_noisy= [5.31393571]
# turn_noisy= [5.70785949]
# fwd_noisy= [4.17326365]
# turn_noisy= [-12.81181283]
# fwd_noisy= [5.49515624]
# turn_noisy= [1.55260291]
# fwd_noisy= [5.19212022]
# turn_noisy= [4.49692357]
# fwd_noisy= [4.88458733]
# turn_noisy= [17.94589816]
# fwd_noisy= [4.59575524]
# turn_noisy= [11.18699242]
# fwd_noisy= [5.14214662]
# turn_noisy= [3.30206627]
# fwd_noisy= [5.26168023]
# turn_noisy= [1.77615665]
# fwd_noisy= [5.6719633]
# turn_noisy= [1.36742251]
# fwd_noisy= [4.69861161]
# turn_noisy= [5.28463685]
# fwd_noisy= [5.96534578]
# turn_noisy= [-6.25260966]
# fwd_noisy= [5.44108142]
# turn_noisy= [8.05578796]
# fwd_noisy= [5.7115209]
# turn_noisy= [-8.0855691]
# fwd_noisy= [4.5005074]
# turn_noisy= [15.4425958]
# fwd_noisy= [4.64723366]
# turn_noisy= [-5.71290945]
# fwd_noisy= [4.65089256]
# turn_noisy= [7.9788871]
# fwd_noisy= [5.03328909]
# turn_noisy= [-12.89411408]
# fwd_noisy= [5.50896395]
# turn_noisy= [14.36674095]
# fwd_noisy= [4.94529747]
# turn_noisy= [2.03411565]
# fwd_noisy= [5.01164917]
# turn_noisy= [-4.37561831]
# fwd_noisy= [4.44701198]
# turn_noisy= [0.29853733]
# fwd_noisy= [5.07909777]
# turn_noisy= [3.41355168]
# fwd_noisy= [5.45271622]
# turn_noisy= [-3.60366026]
# fwd_noisy= [5.15317612]
# turn_noisy= [7.03692388]
# fwd_noisy= [5.22743141]
# turn_noisy= [2.61768614]
# fwd_noisy= [5.28255696]
# turn_noisy= [1.98140603]
# fwd_noisy= [4.70768978]
# turn_noisy= [11.5024588]
# fwd_noisy= [4.92580275]
# turn_noisy= [-9.66815988]
# fwd_noisy= [4.84472263]
# turn_noisy= [-7.46807766]
# fwd_noisy= [4.89196586]
# turn_noisy= [1.56774347]
# fwd_noisy= [0.3619879]
# turn_noisy= [-32.32532702]
# fwd_noisy= [5.23278747]
# turn_noisy= [0.23249567]
# fwd_noisy= [4.84877071]
# turn_noisy= [-7.44344047]
# fwd_noisy= [5.58842157]
# turn_noisy= [5.87397334]
# fwd_noisy= [5.82901352]
# turn_noisy= [-10.50730944]
# fwd_noisy= [5.85133751]
# turn_noisy= [-2.23513339]
# fwd_noisy= [5.39037705]
# turn_noisy= [3.8863754]
# fwd_noisy= [5.5089633]
# turn_noisy= [-12.98973843]
# fwd_noisy= [4.9846375]
# turn_noisy= [-3.28703416]
# fwd_noisy= [5.13534705]
# turn_noisy= [-9.9575888]
# fwd_noisy= [4.93047001]
# turn_noisy= [7.56311462]
# fwd_noisy= [4.5417007]
# turn_noisy= [-13.50267734]
# fwd_noisy= [4.20251673]
# turn_noisy= [-1.48913494]
# fwd_noisy= [4.56206249]
# turn_noisy= [20.95480398]
# fwd_noisy= [4.47618478]
# turn_noisy= [6.52844363]
# fwd_noisy= [5.38635334]
# turn_noisy= [4.75432078]
# fwd_noisy= [5.50151025]
# turn_noisy= [-6.03445042]
# fwd_noisy= [5.15754234]
# turn_noisy= [1.57242723]
# fwd_noisy= [5.21828112]
# turn_noisy= [-14.46037803]
# fwd_noisy= [5.35229443]
# turn_noisy= [-12.45254246]
# fwd_noisy= [5.00873462]
# turn_noisy= [14.6415777]
# fwd_noisy= [5.35893418]
# turn_noisy= [0.44542332]
# fwd_noisy= [4.64593404]
# turn_noisy= [7.11547548]
# fwd_noisy= [5.12621679]
# turn_noisy= [-12.01587936]
# fwd_noisy= [4.96514664]
# turn_noisy= [30.55874613]
# fwd_noisy= [5.72060187]
# turn_noisy= [5.83491462]
# fwd_noisy= [-0.20199613]
# turn_noisy= [-22.7815813]
# fwd_noisy= [5.59693012]
# turn_noisy= [4.90459676]
# fwd_noisy= [4.65222005]
# turn_noisy= [1.41284348]
# fwd_noisy= [4.28325655]
# turn_noisy= [-8.56027014]
# fwd_noisy= [-0.1668583]
# turn_noisy= [-26.81548759]
# fwd_noisy= [0.05295632]
# turn_noisy= [-10.95603145]
# fwd_noisy= [5.03661562]
# turn_noisy= [-3.73946714]
# fwd_noisy= [5.14421837]
# turn_noisy= [-0.36500005]
# fwd_noisy= [4.44907441]
# turn_noisy= [0.00046897]
# fwd_noisy= [5.06151179]
# turn_noisy= [-18.41539528]
# fwd_noisy= [5.29871502]
# turn_noisy= [-7.25920755]
# fwd_noisy= [5.66900423]
# turn_noisy= [5.92617333]
# fwd_noisy= [3.92718816]
# turn_noisy= [4.95373865]
# fwd_noisy= [5.62792018]
# turn_noisy= [-2.35368091]
# fwd_noisy= [5.31405449]
# turn_noisy= [8.4377253]
# fwd_noisy= [4.85523592]
# turn_noisy= [6.62356797]
# fwd_noisy= [5.05095712]
# turn_noisy= [-7.79147301]
# fwd_noisy= [5.12590044]
# turn_noisy= [-4.51322051]
# fwd_noisy= [5.17914047]
# turn_noisy= [12.68287082]
# fwd_noisy= [5.08103298]
# turn_noisy= [-11.51679351]
# fwd_noisy= [4.89082811]
# turn_noisy= [8.3733171]
# fwd_noisy= [4.95094172]
# turn_noisy= [-12.4170455]
# fwd_noisy= [4.76656986]
# turn_noisy= [2.55029773]
# fwd_noisy= [4.45102714]
# turn_noisy= [-3.2681743]
# fwd_noisy= [5.21396872]
# turn_noisy= [8.49318855]
# fwd_noisy= [5.62432728]
# turn_noisy= [-5.73864101]
# fwd_noisy= [5.36440254]
# turn_noisy= [16.30003035]
# fwd_noisy= [5.33028014]
# turn_noisy= [-2.44804384]
# fwd_noisy= [4.9759855]
# turn_noisy= [6.76542667]
# fwd_noisy= [5.08774118]
# turn_noisy= [-11.56620753]
# fwd_noisy= [5.07152682]
# turn_noisy= [-4.03967842]
# fwd_noisy= [4.44912588]
# turn_noisy= [12.27016371]
# fwd_noisy= [0.40366876]
# turn_noisy= [-16.39425429]
# fwd_noisy= [-0.0709048]
# turn_noisy= [-21.15857291]
# fwd_noisy= [0.1738051]
# turn_noisy= [-29.5880091]
# fwd_noisy= [0.32622401]
# turn_noisy= [-52.71310935]
# fwd_noisy= [5.85722143]
# turn_noisy= [-13.91434949]
# fwd_noisy= [5.0693459]
# turn_noisy= [-2.31597873]
# fwd_noisy= [4.52681099]
# turn_noisy= [-4.0196982]
# fwd_noisy= [5.44875066]
# turn_noisy= [5.25015458]
# fwd_noisy= [5.17183805]
# turn_noisy= [-7.3320122]
# fwd_noisy= [5.17106021]
# turn_noisy= [-3.53071644]
# fwd_noisy= [3.83483411]
# turn_noisy= [-10.69902683]
# fwd_noisy= [4.75950886]
# turn_noisy= [8.32736627]
# fwd_noisy= [4.3337785]
# turn_noisy= [6.8409027]
# fwd_noisy= [5.38393667]
# turn_noisy= [0.03581523]
# fwd_noisy= [4.75082934]
# turn_noisy= [8.76267177]
# fwd_noisy= [5.67023316]
# turn_noisy= [-6.35695983]
# fwd_noisy= [5.13823672]
# turn_noisy= [8.78997459]
# fwd_noisy= [4.88915698]
# turn_noisy= [9.01937949]
# fwd_noisy= [4.75517282]
# turn_noisy= [-3.00947206]
# fwd_noisy= [4.85848172]
# turn_noisy= [9.05805482]
# fwd_noisy= [6.27573471]
# turn_noisy= [-17.16038526]
# fwd_noisy= [4.96663055]
# turn_noisy= [-1.63475398]
# fwd_noisy= [4.58614501]
# turn_noisy= [2.4806449]
# fwd_noisy= [5.13166752]
# turn_noisy= [9.76259152]
# fwd_noisy= [5.65270969]
# turn_noisy= [-5.34114701]
# fwd_noisy= [5.21249801]
# turn_noisy= [16.27723433]
# fwd_noisy= [4.64344402]
# turn_noisy= [21.47955098]
# fwd_noisy= [5.89829589]
# turn_noisy= [-10.19078901]
# fwd_noisy= [4.39918566]
# turn_noisy= [11.02504513]
# fwd_noisy= [5.57972499]
# turn_noisy= [19.83781101]
# fwd_noisy= [5.5350427]
# turn_noisy= [-3.65372931]
# fwd_noisy= [4.68143829]
# turn_noisy= [3.3121694]
# fwd_noisy= [3.85407245]
# turn_noisy= [-3.98584851]
# fwd_noisy= [5.09724312]
# turn_noisy= [-5.33911649]
# fwd_noisy= [5.4870321]
# turn_noisy= [-2.64940972]
# fwd_noisy= [4.04586486]
# turn_noisy= [12.53200602]
# fwd_noisy= [5.19616809]
# turn_noisy= [-5.38198484]
# fwd_noisy= [4.84609723]
# turn_noisy= [-18.50814081]
# fwd_noisy= [4.89602796]
# turn_noisy= [-7.92862273]
# fwd_noisy= [5.46311971]
# turn_noisy= [-6.59648159]
# fwd_noisy= [4.8422398]
# turn_noisy= [-6.76013946]
# fwd_noisy= [5.48435022]
# turn_noisy= [-10.51807408]
# fwd_noisy= [4.91135725]
# turn_noisy= [1.71055319]
# fwd_noisy= [5.22817778]
# turn_noisy= [1.98320849]
# fwd_noisy= [4.61520343]
# turn_noisy= [3.75131716]
# fwd_noisy= [4.44460135]
# turn_noisy= [9.10609913]
# fwd_noisy= [4.28106588]
# turn_noisy= [-2.48620034]
# fwd_noisy= [4.62425247]
# turn_noisy= [-2.11628631]
# fwd_noisy= [5.48487411]
# turn_noisy= [-10.17003405]
# fwd_noisy= [6.28857094]
# turn_noisy= [-0.32048652]
# fwd_noisy= [5.16226922]
# turn_noisy= [5.44176465]
# fwd_noisy= [6.36325933]
# turn_noisy= [-4.69364186]
# fwd_noisy= [4.79550921]
# turn_noisy= [-8.34040705]
# fwd_noisy= [4.50384688]
# turn_noisy= [-11.63100554]
# fwd_noisy= [4.99734818]
# turn_noisy= [13.91706929]
# fwd_noisy= [5.84167893]
# turn_noisy= [2.78368154]
# fwd_noisy= [4.64580334]
# turn_noisy= [2.47336492]
# fwd_noisy= [5.35409815]
# turn_noisy= [14.09473766]
# fwd_noisy= [4.96069733]
# turn_noisy= [1.74088437]
# fwd_noisy= [4.82659605]
# turn_noisy= [12.66723786]
# fwd_noisy= [5.9380917]
# turn_noisy= [8.61852795]
# fwd_noisy= [4.45858654]
# turn_noisy= [1.50917612]
# fwd_noisy= [5.01894238]
# turn_noisy= [-7.13609441]
# fwd_noisy= [4.95247212]
# turn_noisy= [-8.8408923]
# fwd_noisy= [5.23583578]
# turn_noisy= [-5.32140191]
# fwd_noisy= [5.01205696]
# turn_noisy= [0.40785543]
# fwd_noisy= [4.96932676]
# turn_noisy= [-3.93883361]
# fwd_noisy= [4.61654369]
# turn_noisy= [-11.37816092]
# fwd_noisy= [4.90051236]
# turn_noisy= [-6.28464693]
# fwd_noisy= [5.08537318]
# turn_noisy= [-1.88197869]
# fwd_noisy= [4.07191291]
# turn_noisy= [-0.62998525]
# fwd_noisy= [4.24855876]
# turn_noisy= [5.22506833]
# fwd_noisy= [4.91307312]
# turn_noisy= [3.38114498]
# fwd_noisy= [4.18247358]
# turn_noisy= [-7.49915719]
# fwd_noisy= [5.14423925]
# turn_noisy= [21.98419181]
# fwd_noisy= [5.19325652]
# turn_noisy= [-8.59985055]
# fwd_noisy= [5.42491169]
# turn_noisy= [0.53937675]
# fwd_noisy= [4.59886144]
# turn_noisy= [-5.54404804]
# fwd_noisy= [5.6066045]
# turn_noisy= [-11.39074308]
# fwd_noisy= [4.769818]
# turn_noisy= [7.40463706]
# fwd_noisy= [4.76266378]
# turn_noisy= [8.81771339]
# fwd_noisy= [5.18762137]
# turn_noisy= [-7.07497259]
# fwd_noisy= [4.14549616]
# turn_noisy= [-8.91256441]
# fwd_noisy= [4.83878812]
# turn_noisy= [-6.46056529]
# fwd_noisy= [5.36452313]
# turn_noisy= [-0.84361535]
# fwd_noisy= [5.71982792]
# turn_noisy= [11.90514072]
# fwd_noisy= [5.14879274]
# turn_noisy= [15.61962778]
# fwd_noisy= [3.43821951]
# turn_noisy= [1.18838117]
# fwd_noisy= [5.83541294]
# turn_noisy= [-4.71593541]
# fwd_noisy= [5.57025484]
# turn_noisy= [-8.57936017]
# fwd_noisy= [6.29370393]
# turn_noisy= [15.23323024]
# fwd_noisy= [5.86797293]
# turn_noisy= [4.60397779]
# fwd_noisy= [4.19394932]
# turn_noisy= [-3.29075779]
